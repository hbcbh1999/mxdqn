# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
csv_list = glob.glob('./logs/*/results.csv')

# %%
for item in csv_list:
    data = pd.read_csv(item)
    loss = pd.read_csv(item[:-11]+'learning.csv')
    plt.xkcd()
    fig = plt.figure(figsize=(8, 18))
    
    plt.subplot(311)
    plt.plot(data['epoch'], data['reward_per_epoch'], '-')
    plt.xlabel('Epoch')
    plt.ylabel('Reward')
    title = item.split('/')[-2].split('-')[0][:-3]
    plt.title(title)
    
    plt.subplot(311)
    plt.plot(data['epoch'], data['reward_per_epoch'], '-')
    plt.xlabel('Epoch')
    plt.ylabel('Reward')
    title = item.split('/')[-2].split('-')[0][:-3]
    plt.title(title)   
    
    
    plt.savefig('figs/' + title)
    break

# %%
loss
# Out:
#        mean_loss   epsilon
# 0       2.456091  0.999614
# 1       3.191468  0.998624
# 2       1.105900  0.998417
# 3       1.149425  0.997904
# 4      10.884942  0.997709
# 5       1.187212  0.997402
# 6       1.191091  0.997061
# 7       1.267143  0.996660
# 8       1.109643  0.996030
# 9       1.279821  0.995670
# 10      1.034145  0.995406
# 11      0.907913  0.995223
# 12      1.081043  0.994863
# 13      1.023435  0.994546
# 14      0.869204  0.994194
# 15      0.946473  0.993836
# 16      0.947726  0.993264
# 17      0.934707  0.992888
# 18      0.950207  0.992546
# 19      0.967764  0.992279
# 20      7.962037  0.992001
# 21      0.904054  0.991622
# 22      1.028324  0.991337
# 23      0.997040  0.990847
# 24      1.416406  0.990428
# 25      0.945958  0.989627
# 26      0.824329  0.988825
# 27      0.867470  0.988351
# 28      0.644955  0.988168
# 29      1.302403  0.987982
# ...          ...       ...
# 35931   1.575475  0.100000
# 35932   1.516855  0.100000
# ...

# %%
pd.read_csv('logs/alien_12-09-08-11_0p00025_0p99/learning.csv')
# Out:
#         mean_loss   epsilon
# 0        5.415579  0.999896
# 1        2.299024  0.999721
# 2        2.388034  0.999530
# 3        1.844720  0.999340
# 4        2.058060  0.999121
# 5        1.598251  0.998901
# 6        1.826872  0.998762
# 7        2.004290  0.998628
# 8        1.889048  0.998515
# 9        1.897296  0.998327
# 10       1.727054  0.998213
# 11       2.170875  0.998083
# 12       1.900021  0.997932
# 13       2.075069  0.997763
# 14       1.925578  0.997583
# 15       1.695674  0.997442
# 16       6.826063  0.997289
# 17       1.815961  0.997146
# 18       1.662323  0.996966
# 19       2.183259  0.996737
# 20       1.954375  0.996386
# 21       1.882632  0.996233
# 22       2.111167  0.996099
# 23       4.593744  0.995738
# 24       2.141089  0.995578
# 25       1.694918  0.995406
# 26       1.806062  0.995100
# 27       1.870079  0.994938
# 28       2.077285  0.994767
# 29       2.159037  0.994610
# ...           ...       ...
# 148573   6.154891  0.100000
# ...
